# %% [markdown]
# <h1 dir=rtl align=center style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# پشت نیمکت چی می‌گذره؟
# </font>
# </h1>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn">
# در این بخش از مسابقه، با مجموعه‌داده‌ای روبه‌رو هستید که تصویری گسترده و چندبعدی از وضعیت تحصیلی، رفتاری و خانوادگی دانش‌آموزان در یک محیط آموزشی دیجیتال یا ترکیبی ارائه می‌دهد. وظیفه شما این است که با تحلیل این داده‌ها، وضعیت کلی هر دانش‌آموز را پیش‌بینی و دسته‌بندی کنید.
# </font>
# </p>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
# در فایل اولیه‌ی این سوال، یک پوشه با نام <code>Data</code> وجود دارد که شامل ۲ فایل <code>train.csv</code> و <code>test.csv</code>.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#
# </font>
# </p>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
# هرستون این مجموعه‌داده با توجه به ماهیت خود می‌تواند مقادیر عددی یا رشته‌ای داشته باشد. برای آشنایی بیشتر با مجموعه‌داده، پیشنهاد می‌شود هرستون به صورت جداگانه بررسی شود.</font>
# </p>

# %% [markdown]
# <h4 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده آموزشی (train.csv)
# </font>
# </h4>
#
# <div dir="rtl">
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#
# فایل <code>train.csv</code> دارای `384` سطر و `17` ستون می‌باشد که ستون‌های آن به شرح زیر می‌باشد:
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>gender</code>| جنسیت دانش‌آموز را مشخص می‌کند.|
# |<code>NationalITy</code>| تابعیت یا ملیت دانش‌آموز را مشخص می‌کند.|
# |<code>PlaceofBirth</code>| محل تولد دانش‌آموز را مشخص می‌کند.|
# |<code>StageID</code>|دوره تحصیلی فعلی دانش‌آموز را مشخص می‌کند.|
# |<code>GradeID</code>| پایه تحصیلی دانش‌آموز در مدرسه را مشخص می‌کند.|
# |<code>SectionID</code>| بخش یا کلاس تقسیم‌بندی شده در یک پایه خاص.|
# |<code>Topic</code>| موضوع یا درس مورد نظر در فعالیت‌های آموزشی.|
# |<code>Semeter</code>| نیم‌سال تحصیلی مربوط به تحصیل دانش‌آموز.|
# |<code>Relation</code>| رابطه پاسخ‌دهنده (ولی دانش‌آموز) با دانش‌آموز.|
# |<code>raisedhands</code>| تعداد دفعاتی که دانش‌آموز در کلاس دست خود را برای پاسخ‌گویی بالا برده است.|
# |<code>VisITedResources</code>| تعداد دفعاتی که دانش‌آموز منابع آموزشی آنلاین را مشاهده کرده است.|
# |<code>AnnouncementsView</code>|تعداد دفعاتی که دانش‌آموز اعلانات (اطلاعیه‌ها) را مشاهده کرده است.|
# |<code>Discussion</code>| تعداد مشارکت‌های دانش‌آموز در بحث‌های آموزشی آنلاین یا کلاسی.|
# |<code>ParentAnsweringSurvey</code>| آیا والدین در نظرسنجی‌های مدرسه شرکت کرده‌اند؟|
# |<code>ParentschoolSatisfaction</code>| میزان رضایت والدین از مدرسه. |
# |<code>StudentAbsenceDays</code>| تعداد روزهای غیبت دانش‌آموز در مدرسه.|
# |<code>Class</code>| متغیر هدف؛ برچسب عملکرد نهایی دانش‌آموز به صورت سطحی.|
#
#
# <br>
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h4 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معرفی مجموعه داده آزمون (test.csv)
# </font>
# </h4>
#
# <div dir="rtl">
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
# هدف نهایی شما این است که با استفاده از یک مدل با استفاده از یادگیری ماشین یا یادگیری عمیق سطح هر دانش‌آموز را به ازای هر نمونه آزمایش پیش‌بینی کند.
# </font>
# </div>
#
#
# <div dir="rtl">
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#
# فایل <code>test.csv</code> دارای `206` سطر و `16` ستون می‌باشد که ستون‌های آن همانند مجموعه  آموزش هستند ولی شامل ستون هدف نیست.
#
#
# </font>
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این قسمت کتاب‌خانه‌ها و ابزار مورد نیاز خود را <code>import</code> کنید و فایل داده‌ها را که در پوشه‌ی <code>Data</code> و که با نام‌های <code>train.csv</code> و <code>test.csv</code> ذخیره‌شده‌اند را بخوانید و وارد محیط کار خود کنید.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from  sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score,make_scorer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
data_set_name_kaggle=""

train_data_set_name="/train.csv"
test_data_set_name="/test.csv"

import os
import sys


def setup_environment(): # for less manual work when move it from local to colab and kaggle
    """
    environment detection that checks for kaggle, colab and colab at the end
    """
    
    env_info = {
        'environment': 'unknown',
        'is_colab': False,
        'is_kaggle': False,
        'is_local': False,
        'base_path': '',
        'data_path': '',
        'notebook_path': ''
    }
    
    # check for kaggle first  
    kaggle_indicators = [
        'KAGGLE_KERNEL_RUN_TYPE' in os.environ,
        'KAGGLE_URL_BASE' in os.environ,
        '/kaggle/' in os.getcwd(),
        any('kaggle' in path.lower() for path in sys.path),
        os.path.exists('/kaggle')
    ]
    
    if all(kaggle_indicators):
        env_info['environment'] = 'kaggle'
        env_info['is_kaggle'] = True
        env_info['base_path'] = '/kaggle/working'
        env_info['data_path'] = f'/kaggle/input'
        env_info['notebook_path'] = '/kaggle/working'
        print(" Environment: Kaggle Notebook")
    
    # then Colab
    elif 'google.colab' in sys.modules:
        env_info['environment'] = 'google_colab'
        env_info['is_colab'] = True
        env_info['base_path'] = '/content'
        env_info['data_path'] = f'/content/drive/MyDrive/Colab Notebooks/data_sets'
        env_info['notebook_path'] = '/content/drive/MyDrive/Colab Notebooks'
        print(" Environment: Google Colab")
        from google.colab import drive
        drive.mount('/content/drive')
        
    # local system at last
    else:
        env_info['environment'] = 'local_system'
        env_info['is_local'] = True
        env_info['base_path'] = os.getcwd()
        env_info['data_path'] = os.path.join(os.getcwd(), 'data_sets')
        env_info['notebook_path'] = os.getcwd()
        print(" Environment: Local System")
    

    
    return env_info



environment = setup_environment()
print(f"Base path: {environment['base_path']}","\n")
print(f"Data path: {environment['data_path']}")

train_csv_path = environment["data_path"]+train_data_set_name
test_csv_path = environment["data_path"]+test_data_set_name

df_train=pd.read_csv(train_csv_path)
df_test=pd.read_csv(test_csv_path)
if df_train.equals(df_test) :
    print('you only have one dataset. data_test is same as data_train')
    data_train, data_test = train_test_split(df_train,test_size=0.2,random_state=42,shuffle=True) 

else:
    data_train = df_train
    data_test = df_test

# using df_train, because i don't need data_test
# Out:
#  Environment: Local System
# Base path: /home/aerf123/my_projects/python/Data_analysis_and_science_&_AI/contest/previous/what_happend_behind_the_bench
#
# Data path: /home/aerf123/my_projects/python/Data_analysis_and_science_&_AI/contest/previous/what_happend_behind_the_bench/data_sets

# %%
print(data_train.columns)
data_train.head(5)
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')
#   gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0      M          KW       KuwaIT    lowerlevel    G-02         C       IT
# 1      M          KW       KuwaIT    HighSchool    G-11         B     Math
# 2      M   Palestine    Palestine  MiddleSchool    G-08         A  Geology
# 3      M          KW       KuwaIT    HighSchool    G-09         A       IT
# 4      M      Jordan       Jordan    lowerlevel    G-02         A   Arabic
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        S   Father            0                 3                 10
# 1        S      Mum           73                84                 77
# 2        S   Father           85                88                 79
# 3        F   Father           10                12                  7
# 4        F   Father           20                88                 31
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0           3                    No                      Bad
# 1          81                   Yes                     Good
# 2          70                   Yes                     Good
# 3          33                   Yes                     Good
# 4          28                   Yes                     Good
#
#   StudentAbsenceDays Class
# 0            Above-7     L
# 1            Above-7     H
# 2            Under-7     M
# 3            Above-7     L
# 4            Above-7     M

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#         در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی دلخواهتان، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
#     در این قسمت شما می‌توانید بخشی از داده‌ی موجود را برای اعتبارسنجی در نظر بگیرید.
# </font>
# </p>

# %%
if "Class" in data_train.columns:
    y_target_train=data_train["Class"]
    data_train=data_train.drop(columns="Class")

# %%
data_test
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       F          KW       KuwaIT  MiddleSchool    G-07         A  English
# 1       F       Lybia        Lybia  MiddleSchool    G-07         B  Biology
# 2       M      Jordan    Palestine  MiddleSchool    G-07         A  Biology
# 3       M   Palestine       Jordan  MiddleSchool    G-06         A  English
# 4       M   Palestine    Palestine  MiddleSchool    G-07         A  Biology
# ..    ...         ...          ...           ...     ...       ...      ...
# 91      M          KW       KuwaIT  MiddleSchool    G-08         B  Spanish
# 92      M          KW       KuwaIT  MiddleSchool    G-07         B  Science
# 93      M      Jordan       Jordan  MiddleSchool    G-07         B  Biology
# 94      M          KW       KuwaIT  MiddleSchool    G-07         A       IT
# 95      M   Palestine       Jordan  MiddleSchool    G-07         B  Biology
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         F   Father           19                30                 26
# 1         F      Mum           10                 9                  2
# 2         F      Mum           78                91                 50
# 3         S      Mum           92                31                 42
# 4         S   Father           89                92                 89
# ..      ...      ...          ...               ...                ...
# 91        S   Father           62                61                 82
# 92        S   Father           72                80                 58
# 93        F   Father           50                79                 10
# 94        F   Father            8                 7                 30
# 95        S   Father           99                96                 89
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0           19                   Yes                      Bad
# 1            1                    No                     Good
# 2           40                   Yes                     Good
# 3           27                   Yes                     Good
# 4           83                   Yes                     Good
# ..         ...                   ...                      ...
# 91          40                   Yes                      Bad
# 92          66                   Yes                     Good
# 93          31                    No                      Bad
# 94          40                   Yes                     Good
# 95          84                   Yes                     Good
#
#    StudentAbsenceDays
# 0             Above-7
# 1             Above-7
# 2             Under-7
# 3             Under-7
# 4             Under-7
# ..                ...
# 91            Under-7
# 92            Above-7
# 93            Under-7
# 94            Above-7
# 95            Under-7
#
# [96 rows x 16 columns]

# %%
data_test.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays'],
#       dtype='object')

# %%
print(data_train.info())
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    384 non-null    object
#  1   NationalITy               384 non-null    object
#  2   PlaceofBirth              384 non-null    object
#  3   StageID                   384 non-null    object
#  4   GradeID                   384 non-null    object
#  5   SectionID                 384 non-null    object
#  6   Topic                     384 non-null    object
#  7   Semester                  384 non-null    object
#  8   Relation                  384 non-null    object
#  9   raisedhands               384 non-null    int64
#  10  VisITedResources          384 non-null    int64
#  11  AnnouncementsView         384 non-null    int64
#  12  Discussion                384 non-null    int64
#  13  ParentAnsweringSurvey     384 non-null    object
#  14  ParentschoolSatisfaction  384 non-null    object
#  15  StudentAbsenceDays        384 non-null    object
# dtypes: int64(4), object(12)
# memory usage: 48.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    96 non-null     object
#  1   NationalITy               96 non-null     object
#  2   PlaceofBirth              96 non-null     object
#  3   StageID                   96 non-null     object
#  4   GradeID                   96 non-null     object
#  5   SectionID                 96 non-null     object
#  6   Topic                     96 non-null     object
#  7   Semester                  96 non-null     object
#  8   Relation                  96 non-null     object
#  9   raisedhands               96 non-null     int64
#  10  VisITedResources          96 non-null     int64
#  11  AnnouncementsView         96 non-null     int64
#  12  Discussion                96 non-null     int64
#  13  ParentAnsweringSurvey     96 non-null     object
#  14  ParentschoolSatisfaction  96 non-null     object
#  15  StudentAbsenceDays        96 non-null     object
# dtypes: int64(4), object(12)
# memory usage: 12.1+ KB

# %%
le=LabelEncoder()
for i in data_train.columns[data_train.dtypes == "object"]:
    data_train[i]=le.fit_transform(data_train[i])
    data_test[i]=le.transform(data_test[i])


# for i in data_train.columns[data_train.dtypes == "object"]:
#     data_train=pd.concat([data_train,pd.get_dummies(data_train[i],dtype=np.int8,drop_first=True)],axis=1)
#     data_test=pd.concat([data_test,pd.get_dummies(data_test[i],dtype=np.int8,drop_first=True)],axis=1)
#     data_train=data_train.drop(columns=[i])
#     data_test=data_test.drop(columns=[i])

# %%
# TODO:
print(data_train.isna().sum())
print(data_train.duplicated().sum())
print(data_test.isna().sum())
data_test.duplicated().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# dtype: int64
# 0
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# dtype: int64
# np.int64(0)

# %%
# TODO:
x_features_train=data_train
x_features_test=data_test




scaler=StandardScaler()
scaled_x_features_train=scaler.fit_transform(x_features_train)
scaled_x_features_test=scaler.transform(x_features_test)
scaled_x_features_train=pd.DataFrame(scaled_x_features_train)
scaled_x_features_test=pd.DataFrame(scaled_x_features_test)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# آموزش مدل
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazirmatn;font-size:medium">
# <font face="vazirmatn" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazirmatn;font-size:medium">
# <font face="vazirmatn" size=3>
# توجه داشته باشید که نمونه‌های موجود در مجموعه‌ی آموزش دارای برچسب‌هایی هستند که نشان‌دهنده‌ی سطح هر دانش‌آموز می‌باشند. وظیفه‌ی شما آموزش مدلی است که بتواند با استفاده از ویژگی‌های هر دانش‌آموز، سطح او را برای نمونه‌های موجود در مجموعه‌ی آزمایش پیش‌بینی کرده و به این ترتیب، دانش‌آموزان را دسته‌بندی کند.
# </font>
# </p>

# %%
scored_f1_score=make_scorer(f1_score,response_method="predict")
scored_f1_score.average="weighted"

# %%
x_train,x_val,y_train,y_val=train_test_split(x_features_train,y_target_train,random_state=42,test_size=0.25,stratify=y_target_train)
our_tree=tree.DecisionTreeClassifier(max_depth=19,random_state=42)
our_tree.fit(x_train,y_train)
y_hat=our_tree.predict(x_val)
print(f1_score(y_val,y_hat,average="weighted"))
print(x_features_test.columns)
print(our_tree.feature_importances_)
cross_val_score(estimator=our_tree,X=x_features_train,y=y_target_train,cv=5).mean()
# Out:
# 0.6323352771132377
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays'],
#       dtype='object')
# [0.02733077 0.0534897  0.03945076 0.         0.05056416 0.03225642
#  0.02199043 0.01373099 0.03175318 0.11447113 0.27320177 0.0763764
#  0.09148164 0.02585393 0.00755943 0.14048929]
# np.float64(0.6848598769651402)

# %%
# TODO:

x_train,x_val,y_train,y_val=train_test_split(x_features_train,y_target_train,random_state=42,test_size=0.25,stratify=y_target_train)
scv_classifier=SVC(random_state=42,C=0.1,kernel="rbf",)
scv_classifier.fit(x_train,y_train)
y_hat=scv_classifier.predict(x_val)
print(scv_classifier.score(x_val,y_val))
print(f1_score(y_val,y_hat,average="weighted"))
cross_val_score(estimator=scv_classifier,X=x_features_train,y=y_target_train,cv=5).mean()
# Out:
# 0.5416666666666666
# 0.5103445572195572
# np.float64(0.6196855775803144)

# %%
x_train,x_val,y_train,y_val=train_test_split(x_features_train,y_target_train,random_state=42,test_size=0.25,stratify=y_target_train)
knn=KNeighborsClassifier(n_neighbors=7,metric='l1',p=2)
knn.fit(x_train,y_train)
y_hat=knn.predict(x_val)
print(f1_score(y_val,y_hat,average="weighted"))
cross_val_score(estimator=knn,X=x_features_train,y=y_target_train,cv=5).mean()
# Out:
# 0.6642794261105427
# np.float64(0.6561517429938484)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_features_train, y_target_train,test_size=0.25, random_state=42, stratify=y_target_train)
log_reg = LogisticRegression(penalty="l2",random_state=42,multi_class="multinomial")
log_reg.fit(x_train, y_train)
print(log_reg.score(x_val, y_val) )
cross_val_score(estimator=log_reg,X=x_features_train,y=y_target_train,cv=5).mean()
# Out:
# 0.71875
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# np.float64(0.6771701982228299)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معیار ارزیابی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>F1_score</code> نام دارد.
#     <br>
#     این معیار، سنجه ارزیابی کیفیت مدل شماست. به عبارت بهتر در سامانه داوری هم از همین معیار برای نمره‌دهی استفاده شده است.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه‌ی آموزش یا اعتبارسنجی ارزیابی کنید.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazirmatn" size=3>
#     برای دریافت نمره از این سوال لازم است تا دقت مدل شما از آستانه‌ی ۰.۷ بیشتر باشد.
#     در صورتی که دقت مدل شما از ۰.۷ کمتر باشد نمره شما
#     <b>صفر</b>
#     خواهد شد.
# </font>
# </p>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     پیش‌بینی مدل خود بر روی داده‌های آزمایش (<code>test.csv</code>) را در قالب یک <code>dataframe</code> در متغیری با نام <code>submission</code>ذخیره کنید.  این <code>dataframe</code> باید دارای یک ستون با نام <code>Class</code> باشد که ردیف <code>i</code>ام آن، پیش‌بینی شما برای سطر <code>i</code>ام مجموعه‌داده‌ی آزمون باشد.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |------|---|
# |Class|عملکرد نهایی دانش‌آموز |
#
# </font>
#
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# جدول زیر می‌تواند نمونه‌ای از خروجی مورد انتظار باشد
#
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |Class|
# |:------:|
# |M|
# |M|
# |L|
# |H|
#
#
# <br>
#
# </font>
# </div>
# </center>

# %%
# TODO:
submission=pd.DataFrame()
submission["Class"] = log_reg.predict(scaled_x_features_test)
submission
# Out:
# /home/aerf123/my_projects/python/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
#    Class
# 0      H
# 1      H
# 2      H
# 3      H
# 4      H
# ..   ...
# 91     M
# 92     L
# 93     M
# 94     L
# 95     M
#
# [96 rows x 1 columns]

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazirmatn; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) در غیر این صورت، در پایان مسابقه نمره شما به صفر تغییر خواهد کرد.
#     <br>
#     همچنین اگر از کولب برای اجرای این فایل نوت‌بوک استفاده می‌کنید، قبل از ارسال فایل <code>result.zip</code>، آخرین نسخه‌ی نوت‌بوک خود را دانلود کرده و داخل فایل ارسالی قرار دهید.
# </font>

# %%
import zipfile
import joblib
import os

if not os.path.exists(os.path.join(os.getcwd(), 'notebook.ipynb')):
    # %notebook -e notebook.ipynb

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['notebook.ipynb', 'submission.csv']
compress(file_names)
# Out:
# UsageError: unrecognized arguments: -e
